# %%
import os
import pandas as pd

# Set working directory
os.chdir(
    os.path.join(os.path.expanduser("~"), "tbp/monty_lab/monty_capabilities_analysis")
)

# Read all stats summary
all_stats_df = pd.read_csv("results/20241104_benchmarks_v9/all_stats_summary.csv")

# %%
all_stats_df.head()
# Out:
#                  experiment_name  correct_percentage  incorrect_percentage  \
# 0                dist_agent_10lm            0.986271              0.012152
# 1          dist_agent_10lm_noise            0.978850              0.017069
# 2        dist_agent_10lm_randrot            0.924026              0.075139
# 3  dist_agent_10lm_randrot_noise            0.920130              0.078757
# 4                 dist_agent_1lm            0.992579              0.005566
#
#   most_frequent_mistake  most_frequent_mistake_frequency  precision    recall  \
# 0      flat_screwdriver                               21   0.975300  0.973535
# 1                  fork                               37   0.970739  0.965934
# 2                  fork                              115   0.916446  0.912454
# 3                  fork                              118   0.913612  0.908333
# 4                  fork                                3   0.982621  0.979853
#
# ...

# %%
subset = [
    "surf_agent_1lm",
    "surf_agent_1lm_noise",
    "surf_agent_1lm_randrot",
    "surf_agent_1lm_randrot_noise",
]

# Subset dataframe
subset_df = all_stats_df[all_stats_df["experiment_name"].isin(subset)]

display(subset_df)
# Out:
#                  experiment_name  correct_percentage  incorrect_percentage  \
# 22                surf_agent_1lm            0.990724              0.009276
# 23          surf_agent_1lm_noise            0.979592              0.020408
# 24        surf_agent_1lm_randrot            0.974026              0.025974
# 25  surf_agent_1lm_randrot_noise            0.964750              0.035250
#
#    most_frequent_mistake  most_frequent_mistake_frequency  precision  \
# 22                  fork                                3   0.991076
# 23                  fork                                4   0.981062
# 24                  fork                                6   0.975279
# 25                  fork                                6   0.967320
#
#       recall        f1  accuracy  rotation_error_degrees_mean  \
# 22  0.990724  0.990694  0.990724                     6.652202
# 23  0.979592  0.979550  0.979592                    22.096651
# ...
